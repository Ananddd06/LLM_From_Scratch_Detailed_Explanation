# %%
with open("/Users/anand/Desktop/LLM From Scratch/Dataset/the-verdict.txt" , "r") as f:
    raw_text = f.read()
    
print("The total length of the text is : ", len(raw_text))
print(raw_text[:99])  # Print the first 500 characters of the text
# Out:
# The total length of the text is :  20479
# I HAD always thought Jack Gisburn rather a cheap genius--though a good fellow enough--so it was no

# %%
import re 

text = "Hello ,  world! This , is a test. Let's see: how well does it work?"
result = re.split(r'(\s)' , text)

print(result)
# Out:
# ['Hello', ' ', ',', ' ', '', ' ', 'world!', ' ', 'This', ' ', ',', ' ', 'is', ' ', 'a', ' ', 'test.', ' ', "Let's", ' ', 'see:', ' ', 'how', ' ', 'well', ' ', 'does', ' ', 'it', ' ', 'work?']

# %%
new_res = re.split(r'([,.]|\s)' , text)
print(new_res)
# Out:
# ['Hello', ' ', '', ',', '', ' ', '', ' ', 'world!', ' ', 'This', ' ', '', ',', '', ' ', 'is', ' ', 'a', ' ', 'test', '.', '', ' ', "Let's", ' ', 'see:', ' ', 'how', ' ', 'well', ' ', 'does', ' ', 'it', ' ', 'work?']

# %%
results = [list for list in new_res if list.strip()]
print(results)
# Out:
# ['Hello', ',', 'world!', 'This', ',', 'is', 'a', 'test', '.', "Let's", 'see:', 'how', 'well', 'does', 'it', 'work?']

# %%
text_new = "Hello , world! Is this-- a test?"
res = re.split(r'([,.:;"()\!]|--|\s)', text_new)
res = [item.strip() for item in res if item.strip()]
print(res)
# Out:
# ['Hello', ',', 'world', '!', 'Is', 'this', '--', 'a', 'test?']

# %%
import re

pattern = r"(--|['\"!?,.:;()])|\s+"
preprocessed_text = re.split(pattern, raw_text)
preprocessed_text = [t for t in preprocessed_text if t and not t.isspace()]

print(preprocessed_text[:50])
# Out:
# ['I', 'HAD', 'always', 'thought', 'Jack', 'Gisburn', 'rather', 'a', 'cheap', 'genius', '--', 'though', 'a', 'good', 'fellow', 'enough', '--', 'so', 'it', 'was', 'no', 'great', 'surprise', 'to', 'me', 'to', 'hear', 'that', ',', 'in', 'the', 'height', 'of', 'his', 'glory', ',', 'he', 'had', 'dropped', 'his', 'painting', ',', 'married', 'a', 'rich', 'widow', ',', 'and', 'established', 'himself']

# %%
print(len(preprocessed_text))
# Out:
# 4654

# %% [markdown]
# #### The above is the tokenise word of the verdixt text , we stored that in the variable called tokens from that we are going to convert that into vacobolary and gonaa asign an each indvidual token id

# %%
all_words = sorted(set(preprocessed_text))
print("Total unique words in the text : ", len(all_words))
# Out:
# Total unique words in the text :  1139

# %%
vocab = {token:integer for integer, token in enumerate(all_words)}

# %%
for i , item in enumerate(vocab):
    if i < 50:
        print(f"Token : {item}  --> Integer : {vocab[item]}")
# Out:
# Token : !  --> Integer : 0
# Token : "  --> Integer : 1
# Token : '  --> Integer : 2
# Token : (  --> Integer : 3
# Token : )  --> Integer : 4
# Token : ,  --> Integer : 5
# Token : --  --> Integer : 6
# Token : .  --> Integer : 7
# Token : :  --> Integer : 8
# Token : ;  --> Integer : 9
# Token : ?  --> Integer : 10
# Token : A  --> Integer : 11
# Token : Ah  --> Integer : 12
# Token : Among  --> Integer : 13
# Token : And  --> Integer : 14
# Token : Are  --> Integer : 15
# Token : Arrt  --> Integer : 16
# Token : As  --> Integer : 17
# Token : At  --> Integer : 18
# Token : Be  --> Integer : 19
# Token : Begin  --> Integer : 20
# Token : Burlington  --> Integer : 21
# Token : But  --> Integer : 22
# Token : By  --> Integer : 23
# Token : Carlo  --> Integer : 24
# Token : Chicago  --> Integer : 25
# Token : Claude  --> Integer : 26
# Token : Come  --> Integer : 27
# Token : Croft  --> Integer : 28
# Token : Destroyed  --> Integer : 29
# Token : Devonshire  --> Integer : 30
# Token : Don  --> Integer : 31
# Token : Dubarry_  --> Integer : 32
# Token : Emperors  --> Integer : 33
# Token : Florence  --> Integer : 34
# Token : For  --> Integer : 35
# Token : Gallery  --> Integer : 36
# Token : Gideon  --> Integer : 37
# Token : Gisburn  --> Integer : 38
# Token : Gisburns  --> Integer : 39
# Token : Grafton  --> Integer : 40
# Token : Greek  --> Integer : 41
# Token : Grindle  --> Integer : 42
# Token : Grindles  --> Integer : 43
# Token : HAD  --> Integer : 44
# Token : Had  --> Integer : 45
# Token : Hang  --> Integer : 46
# Token : Has  --> Integer : 47
# Token : He  --> Integer : 48
# Token : Her  --> Integer : 49

# %%
class SimpleTokenizerV1:
    def __init__(self, vocab):
        self.str_to_int = vocab
        self.int_to_str = {i:s for s,i in vocab.items()}
    
    def encode(self, text):
        preprocessed = re.split(r'([,.:;?_!"()\']|--|\s)', text)
                                
        preprocessed = [
            item.strip() for item in preprocessed if item.strip()
        ]
        ids = [self.str_to_int[s] for s in preprocessed]
        return ids
        
    def decode(self, ids):
        text = " ".join([self.int_to_str[i] for i in ids])
        # Replace spaces before the specified punctuations
        text = re.sub(r'\s+([,.?!"()\'])', r'\1', text)
        return text

# %%
tokenizer = SimpleTokenizerV1(vocab)

text = """"It's the last he painted, you know," 
           Mrs. Gisburn said with pardonable pride."""
ids = tokenizer.encode(text)
print(ids)
# Out:
# [1, 56, 2, 859, 997, 612, 544, 756, 5, 1135, 606, 5, 1, 67, 7, 38, 860, 1117, 764, 803, 7]

# %%
tokenizer.decode(ids)
# Out:
# '" It\' s the last he painted, you know," Mrs. Gisburn said with pardonable pride.'

# %%
all_words = sorted(set(preprocessed_text))
all_words.extend(["<|endoftext|>", "<|unk|>"])

vocab = {token:integer for integer, token in enumerate(all_words)}

# %%
len(vocab.items())
# Out:
# 1141

# %%
for i, item in enumerate(list(vocab.items())[-5:]):
    print(item)
# Out:
# ('younger', 1136)
# ('your', 1137)
# ('yourself', 1138)
# ('<|endoftext|>', 1139)
# ('<|unk|>', 1140)

# %%
class SimpleTokenizerV2:
    def __init__(self, vocab):
        self.str_to_int = vocab
        self.int_to_str = { i:s for s,i in vocab.items()}
    
    def encode(self, text):
        preprocessed = re.split(r'([,.:;?_!"()\']|--|\s)', text)
        preprocessed = [item.strip() for item in preprocessed if item.strip()]
        preprocessed = [
            item if item in self.str_to_int 
            else "<|unk|>" for item in preprocessed
        ]

        ids = [self.str_to_int[s] for s in preprocessed]
        return ids
        
    def decode(self, ids):
        text = " ".join([self.int_to_str[i] for i in ids])
        # Replace spaces before the specified punctuations
        text = re.sub(r'\s+([,.:;?!"()\'])', r'\1', text)
        return text

# %%
tokenizer = SimpleTokenizerV2(vocab)

text1 = "Hello, do you like tea?"
text2 = "In the sunlit terraces of the palace."

text = " <|endoftext|> ".join((text1, text2))

print(text)
# Out:
# Hello, do you like tea? <|endoftext|> In the sunlit terraces of the palace.

# %%
tokenizer.encode(text)
# Out:
# [1140, 5, 368, 1135, 638, 984, 10, 1139, 55, 997, 965, 993, 732, 997, 1140, 7]

# %%
tokenizer.decode(tokenizer.encode(text))
# Out:
# '<|unk|>, do you like tea? <|endoftext|> In the sunlit terraces of the <|unk|>.'

# %%
! pip3 install tiktoken
# Out:
# Collecting tiktoken
#   Downloading tiktoken-0.12.0-cp39-cp39-macosx_11_0_arm64.whl.metadata (6.7 kB)
# Collecting regex>=2022.1.18 (from tiktoken)
#   Downloading regex-2025.11.3-cp39-cp39-macosx_11_0_arm64.whl.metadata (40 kB)
# Requirement already satisfied: requests>=2.26.0 in /opt/anaconda3/envs/mlproj/lib/python3.9/site-packages (from tiktoken) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/envs/mlproj/lib/python3.9/site-packages (from requests>=2.26.0->tiktoken) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/mlproj/lib/python3.9/site-packages (from requests>=2.26.0->tiktoken) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/mlproj/lib/python3.9/site-packages (from requests>=2.26.0->tiktoken) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/mlproj/lib/python3.9/site-packages (from requests>=2.26.0->tiktoken) (2025.1.31)
# Downloading tiktoken-0.12.0-cp39-cp39-macosx_11_0_arm64.whl (997 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 997.1/997.1 kB 721.5 kB/s eta 0:00:00a 0:00:01
# Downloading regex-2025.11.3-cp39-cp39-macosx_11_0_arm64.whl (288 kB)
# Installing collected packages: regex, tiktoken
# Successfully installed regex-2025.11.3 tiktoken-0.12.0

# %%
import importlib
import tiktoken

print("tiktoken version:", importlib.metadata.version("tiktoken"))
# Out:
# tiktoken version: 0.12.0

# %%
tokenizer = tiktoken.get_encoding("gpt2")

# %%
text = (
    "Hello, do you like tea? <|endoftext|> In the sunlit terraces"
     "of someunknownPlace."
)

integers = tokenizer.encode(text, allowed_special={"<|endoftext|>"})

print(integers)
# Out:
# [15496, 11, 466, 345, 588, 8887, 30, 220, 50256, 554, 262, 4252, 18250, 8812, 2114, 1659, 617, 34680, 27271, 13]

# %%
strings = tokenizer.decode(integers)

print(strings)
# Out:
# Hello, do you like tea? <|endoftext|> In the sunlit terracesof someunknownPlace.

# %%
integers = tokenizer.encode("Akwirw ier")
print(integers)

strings = tokenizer.decode(integers)
print(strings)
# Out:
# [33901, 86, 343, 86, 220, 959]
# Akwirw ier

# %%
with open("/Users/anand/Desktop/LLM From Scratch/Dataset/the-verdict.txt", "r", encoding="utf-8") as f:
    raw_text = f.read()

enc_text = tokenizer.encode(raw_text)
print(len(enc_text))
# Out:
# 5145

# %%
enc_sample = enc_text[50:]

# %%
context_size = 4

x = enc_sample[:context_size]
y = enc_sample[1:context_size+1]

print(f"x: {x}")
print(f"y:      {y}")
# Out:
# x: [290, 4920, 2241, 287]
# y:      [4920, 2241, 287, 257]

# %%
for i in range(1, context_size+1):
    context = enc_sample[:i]
    desired = enc_sample[i]

    print(context, "---->", desired)
# Out:
# [290] ----> 4920
# [290, 4920] ----> 2241
# [290, 4920, 2241] ----> 287
# [290, 4920, 2241, 287] ----> 257

# %%
for i in range(1, context_size+1):
    context = enc_sample[:i]
    desired = enc_sample[i]

    print(tokenizer.decode(context), "---->", tokenizer.decode([desired]))
# Out:
#  and ---->  established
#  and established ---->  himself
#  and established himself ---->  in
#  and established himself in ---->  a

# %%
import torch
from torch.utils.data import Dataset, DataLoader


class GPTDatasetV1(Dataset):
    def __init__(self, txt, tokenizer, max_length, stride):
        self.input_ids = []
        self.target_ids = []

        # Tokenize the entire text
        token_ids = tokenizer.encode(txt, allowed_special={"<|endoftext|>"})

        # Use a sliding window to chunk the book into overlapping sequences of max_length
        for i in range(0, len(token_ids) - max_length, stride):
            input_chunk = token_ids[i:i + max_length]
            target_chunk = token_ids[i + 1: i + max_length + 1]
            self.input_ids.append(torch.tensor(input_chunk))
            self.target_ids.append(torch.tensor(target_chunk))

    def __len__(self):
        return len(self.input_ids)

    def __getitem__(self, idx):
        return self.input_ids[idx], self.target_ids[idx]

# %%
def create_dataloader_v1(txt, batch_size=4, max_length=256, 
                         stride=128, shuffle=True, drop_last=True,
                         num_workers=0):

    # Initialize the tokenizer
    tokenizer = tiktoken.get_encoding("gpt2")

    # Create dataset
    dataset = GPTDatasetV1(txt, tokenizer, max_length, stride)

    # Create dataloader
    dataloader = DataLoader(
        dataset,
        batch_size=batch_size,
        shuffle=shuffle,
        drop_last=drop_last,
        num_workers=num_workers
    )

    return dataloader

# %%
with open("/Users/anand/Desktop/LLM From Scratch/Dataset/the-verdict.txt", "r", encoding="utf-8") as f:
    raw_text = f.read()

# %%
import torch
print("PyTorch version:", torch.__version__)
dataloader = create_dataloader_v1(
    raw_text, batch_size=1, max_length=4, stride=1, shuffle=False
)

data_iter = iter(dataloader)
first_batch = next(data_iter)
print(first_batch)
# Out:
# PyTorch version: 2.8.0
# [tensor([[  40,  367, 2885, 1464]]), tensor([[ 367, 2885, 1464, 1807]])]

# %%
second_batch = next(data_iter)
print(second_batch)
# Out:
# [tensor([[ 367, 2885, 1464, 1807]]), tensor([[2885, 1464, 1807, 3619]])]

# %%
dataloader = create_dataloader_v1(raw_text, batch_size=8, max_length=4, stride=4, shuffle=False)

data_iter = iter(dataloader)
inputs, targets = next(data_iter)
print("Inputs:\n", inputs)
print("\nTargets:\n", targets)
# Out:
# Inputs:
#  tensor([[   40,   367,  2885,  1464],
#         [ 1807,  3619,   402,   271],
#         [10899,  2138,   257,  7026],
#         [15632,   438,  2016,   257],
#         [  922,  5891,  1576,   438],
#         [  568,   340,   373,   645],
#         [ 1049,  5975,   284,   502],
#         [  284,  3285,   326,    11]])
#
# Targets:
#  tensor([[  367,  2885,  1464,  1807],
#         [ 3619,   402,   271, 10899],
#         [ 2138,   257,  7026, 15632],
#         [  438,  2016,   257,   922],
#         [ 5891,  1576,   438,   568],
#         [  340,   373,   645,  1049],
#         [ 5975,   284,   502,   284],
#         [ 3285,   326,    11,   287]])
