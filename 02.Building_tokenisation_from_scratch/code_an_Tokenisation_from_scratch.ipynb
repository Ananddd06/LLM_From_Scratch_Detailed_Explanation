# %%
with open("/Users/anand/Desktop/LLM From Scratch/Dataset/the-verdict.txt" , "r") as f:
    raw_text = f.read()
    
print("The total length of the text is : ", len(raw_text))
print(raw_text[:99])  # Print the first 500 characters of the text
# Out:
# The total length of the text is :  20479
# I HAD always thought Jack Gisburn rather a cheap genius--though a good fellow enough--so it was no

# %%
import re 

text = "Hello ,  world! This , is a test. Let's see: how well does it work?"
result = re.split(r'(\s)' , text)

print(result)
# Out:
# ['Hello', ' ', ',', ' ', '', ' ', 'world!', ' ', 'This', ' ', ',', ' ', 'is', ' ', 'a', ' ', 'test.', ' ', "Let's", ' ', 'see:', ' ', 'how', ' ', 'well', ' ', 'does', ' ', 'it', ' ', 'work?']

# %%
new_res = re.split(r'([,.]|\s)' , text)
print(new_res)
# Out:
# ['Hello', ' ', '', ',', '', ' ', '', ' ', 'world!', ' ', 'This', ' ', '', ',', '', ' ', 'is', ' ', 'a', ' ', 'test', '.', '', ' ', "Let's", ' ', 'see:', ' ', 'how', ' ', 'well', ' ', 'does', ' ', 'it', ' ', 'work?']

# %%
results = [list for list in new_res if list.strip()]
print(results)
# Out:
# ['Hello', ',', 'world!', 'This', ',', 'is', 'a', 'test', '.', "Let's", 'see:', 'how', 'well', 'does', 'it', 'work?']

# %%
text_new = "Hello , world! Is this-- a test?"
res = re.split(r'([,.:;"()\!]|--|\s)', text_new)
res = [item.strip() for item in res if item.strip()]
print(res)
# Out:
# ['Hello', ',', 'world', '!', 'Is', 'this', '--', 'a', 'test?']

# %%
import re

pattern = r"(--|['\"!?,.:;()])|\s+"
preprocessed_text = re.split(pattern, raw_text)
preprocessed_text = [t for t in preprocessed_text if t and not t.isspace()]

print(preprocessed_text[:50])
# Out:
# ['I', 'HAD', 'always', 'thought', 'Jack', 'Gisburn', 'rather', 'a', 'cheap', 'genius', '--', 'though', 'a', 'good', 'fellow', 'enough', '--', 'so', 'it', 'was', 'no', 'great', 'surprise', 'to', 'me', 'to', 'hear', 'that', ',', 'in', 'the', 'height', 'of', 'his', 'glory', ',', 'he', 'had', 'dropped', 'his', 'painting', ',', 'married', 'a', 'rich', 'widow', ',', 'and', 'established', 'himself']

# %%
print(len(preprocessed_text))
# Out:
# 4654

# %% [markdown]
# #### The above is the tokenise word of the verdixt text , we stored that in the variable called tokens from that we are going to convert that into vacobolary and gonaa asign an each indvidual token id

# %%
all_words = sorted(set(preprocessed_text))
print("Total unique words in the text : ", len(all_words))
# Out:
# Total unique words in the text :  1139

# %%
vocab = {token:integer for integer, token in enumerate(all_words)}

# %%
for i , item in enumerate(vocab):
    if i < 50:
        print(f"Token : {item}  --> Integer : {vocab[item]}")
# Out:
# Token : !  --> Integer : 0
# Token : "  --> Integer : 1
# Token : '  --> Integer : 2
# Token : (  --> Integer : 3
# Token : )  --> Integer : 4
# Token : ,  --> Integer : 5
# Token : --  --> Integer : 6
# Token : .  --> Integer : 7
# Token : :  --> Integer : 8
# Token : ;  --> Integer : 9
# Token : ?  --> Integer : 10
# Token : A  --> Integer : 11
# Token : Ah  --> Integer : 12
# Token : Among  --> Integer : 13
# Token : And  --> Integer : 14
# Token : Are  --> Integer : 15
# Token : Arrt  --> Integer : 16
# Token : As  --> Integer : 17
# Token : At  --> Integer : 18
# Token : Be  --> Integer : 19
# Token : Begin  --> Integer : 20
# Token : Burlington  --> Integer : 21
# Token : But  --> Integer : 22
# Token : By  --> Integer : 23
# Token : Carlo  --> Integer : 24
# Token : Chicago  --> Integer : 25
# Token : Claude  --> Integer : 26
# Token : Come  --> Integer : 27
# Token : Croft  --> Integer : 28
# Token : Destroyed  --> Integer : 29
# Token : Devonshire  --> Integer : 30
# Token : Don  --> Integer : 31
# Token : Dubarry_  --> Integer : 32
# Token : Emperors  --> Integer : 33
# Token : Florence  --> Integer : 34
# Token : For  --> Integer : 35
# Token : Gallery  --> Integer : 36
# Token : Gideon  --> Integer : 37
# Token : Gisburn  --> Integer : 38
# Token : Gisburns  --> Integer : 39
# Token : Grafton  --> Integer : 40
# Token : Greek  --> Integer : 41
# Token : Grindle  --> Integer : 42
# Token : Grindles  --> Integer : 43
# Token : HAD  --> Integer : 44
# Token : Had  --> Integer : 45
# Token : Hang  --> Integer : 46
# Token : Has  --> Integer : 47
# Token : He  --> Integer : 48
# Token : Her  --> Integer : 49

# %%
class SimpleTokenizerV1:
    def __init__(self, vocab):
        self.str_to_int = vocab
        self.int_to_str = {i:s for s,i in vocab.items()}
    
    def encode(self, text):
        preprocessed = re.split(r'([,.:;?_!"()\']|--|\s)', text)
                                
        preprocessed = [
            item.strip() for item in preprocessed if item.strip()
        ]
        ids = [self.str_to_int[s] for s in preprocessed]
        return ids
        
    def decode(self, ids):
        text = " ".join([self.int_to_str[i] for i in ids])
        # Replace spaces before the specified punctuations
        text = re.sub(r'\s+([,.?!"()\'])', r'\1', text)
        return text

# %%
tokenizer = SimpleTokenizerV1(vocab)

text = """"It's the last he painted, you know," 
           Mrs. Gisburn said with pardonable pride."""
ids = tokenizer.encode(text)
print(ids)
# Out:
# [1, 56, 2, 859, 997, 612, 544, 756, 5, 1135, 606, 5, 1, 67, 7, 38, 860, 1117, 764, 803, 7]

# %%
tokenizer.decode(ids)
# Out:
# '" It\' s the last he painted, you know," Mrs. Gisburn said with pardonable pride.'
